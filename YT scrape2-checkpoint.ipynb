# %%
import pandas as pd
import googleapiclient.discovery

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAL8zppT4SjtKZyW9snmywqXrOyFnpuJ7w"

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
def youtube_videoid(playlist):
    videolist =[]
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId="PL2fxME0rbf-3UJJT3uux7BaNEgBV0MRvp",maxResults = 50
    )
    response = request.execute()
    
    for i in range (len(response['items'])):
        videolist.append(response['items'][i]['contentDetails']['videoId'])
        
    nextpagetoken = response.get('nextPageToken')
    extra_pages_is_there = True
    
    while extra_pages_is_there:
        if nextpagetoken is None:
            extra_pages_is_there = False
            
        else:
            request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId="PL2fxME0rbf-3UJJT3uux7BaNEgBV0MRvp",maxResults = 50, pageToken = nextpagetoken
    )
            response = request.execute()
            
            for i in range (len(response['items'])):
                videolist.append(response['items'][i]['contentDetails']['videoId'])
        
            nextpagetoken = response.get('nextPageToken')
            

    return videolist

# %%
type(response['items'][0]['contentDetails']['videoId'])
# Out:
# str

# %%
len(response['items'])
# Out:
# 50

# %%
playlistid = 'PL2fxME0rbf-3UJJT3uux7BaNEgBV0MRvp'

# %%
videoinfo = youtube_videoid(playlistid)

# %%
videoinfo
# Out:
# ['87Qczya5HTU',
#  'FEAHnilxy6w',
#  'hLqGReZSr5c',
#  '_DYuHz9VBLo',
#  'HSUsSBk7Wqg',
#  'Q1ZJ3NaVYNA',
#  '4TbdqWbF_PE',
#  'cGNTVozi6Ns',
#  'U5CYdmsR9Sw',
#  '9vyKAKUX0WI',
#  'HixoHQPLFSs',
#  'WNCOSPaOst8',
#  'Pylw3tqzv1U',
#  'ie-n7tIX0EU',
#  '0Ef0Iy9Vf_A',
#  '1ktVglH2xk4',
#  'DvjCPu0odG4',
#  '-xOZP3Ut8J0',
#  'g6UHikNtmy4',
#  'b46D9QnK4jA',
#  'djM5ungZ6mo',
#  'q-cuNO4UanY',
#  '98YROwxUI4Y',
#  'o-OhcV9H6pw',
#  'iWBjHPFrwrM',
#  'NPLa-JDGjcg',
#  '7L-xmfgKomA',
#  'zhzv4eQ97mU',
#  'UHkN7ZrvcNQ',
#  'ctYaB_e4Lb0',
#  'gWs8iAgB6Ek',
#  'IsuZEoMGCsA',
#  'qgFaOB-pNMU',
#  'iptbESNg_mc',
#  '4FXf_bV95yU',
#  'irtdoP3YqCk',
#  'UP-n1nt_jo8',
#  'QKng1gSDq80',
#  'Ep08ccGf0mM',
#  'CW-iEVN8zyk',
#  '-fktVCXDDac',
#  'upet0P9p3xU',
#  'yPtUDNUO7BQ',
#  'p2g8xXjsXyg',
#  '0QtG_bRhGM0',
#  'gTWWJ00Btg4',
#  'AeJO5BV-mWo',
#  'hjglquW-RRA',
#  'Gcox6BZXGxU',
#  '1SyX64uQTgM',
#  'xhFfRLTb45w',
#  'bUXLJiZhb8M',
#  'qTlmXPUOG_k',
#  '9RNoid4y7i4',
#  '_fwHMckVLa8',
#  'iJwbHeQkfDc',
#  'D3AAiauEbsg',
#  'pAgaEWah0kg',
#  '30wmprUlw3I',
#  'LIWTSmk1rlI',
#  'zDj4VoNu0yg',
#  'rRLgWn8sfxw',
#  'uwYJeiECR9E',
#  '93RGd512qrw',
#  'bZPDW062vgU',
#  'g0hFUTMrw2c',
#  'kczsCOd8iKA',
#  'SuU1eAQd900',
#  'aSxNaJvAgl4',
#  '6FVI-0a5YXg',
#  'jj5KiWvIFes',
#  'vnq8i-Rdw08',
#  'P94DxjckQh8',
#  'KooB6MqY-jw',
#  'eNyNtj2zf3A',
#  'hjcvBHuPKrA',
#  'wEXtbPxbDlc',
#  'mBun0K5exVM',
#  'yq5VEdfTZIc',
#  '8Q1OXvjS4yM',
#  'Gz07wOEk8YQ',
#  'sjRjE0lxKQQ',
#  'OY4otpxkeqs',
#  '1I-XQViRFq0',
#  'ZWz7eqbsJmk',
#  'nnK8kbibtgs',
#  'YWA214UdNjk',
#  's9oSsNGC3H0',
#  'hOrqOJ6dXO8',
#  '8fUcU4nkKgs',
#  'X5NBRp9tWO4',
#  'E8hjR3F3QOs',
#  'sp_EtDL5XoI',
#  'EKzofU_8FnU',
#  'NjKTvIMWqxM',
#  'V2ailBMoBoI',
#  '2r2eDY2qTsg',
#  'zwLHJlNMlf4',
#  'SqNehYabteo',
#  'I3O-viCUS3A',
#  'lAfd44X_ZS8',
#  'Mmv7Pt91tO4',
#  '9Tc8-LiAcDU',
#  'jtvysmkz-qM',
#  '2Ms2gG27wyA',
#  'e2JUsVCxqTk',
#  'Oj8QpbNdfwE',
#  'ECc_0RCyYY0',
#  'gAfWIPnbjq0',
#  'reV-oxdm_bU',
#  'OlRXgBRvO7g',
#  'h10GygeLL8I',
#  '-pXIGwbnRwc',
#  'dE2cjK8chQ8',
#  'Rt21-qOqNKg',
#  'wggDXnby1UU',
#  'B348n650iLM',
#  'ViPPMraSTeo',
#  'Rxu-WSCVEi0',
#  'HpkOye6CBp0',
#  'ezzsId2DaUs',
#  'lmbaOrsoPGM',
#  'D7BUvtIWi2s',
#  'Q8zPmD2sU9U',
#  'kg2P_Rpns3Y',
#  'Y5PDep8SmSA',
#  'MRYw1hwWa4s',
#  'LYNKvboBRqQ',
#  'IGLkUuY2SJ0',
#  'u70OpBPtlZo',
#  'HuvpsT--KVE',
#  'm81ihLG1ZWg',
#  'eI8hZWbGCoU',
#  'IEeJGw4yCN8',
#  'WfSE9t1PRtM',
#  'dpNfQ84JTIU',
#  '2WNJO0ybd4g',
#  'sdrZoDy-o-Q',
#  '96KM562jyKI',
#  'aYzxX-T1CUs',
#  'YBDmDCruHmA',
#  '-dNfBZmPly0',
#  'YnhJDPk9SUs',
#  'MOxRi965ybM',
#  'PUBebNPSjm4',
#  'BNCZOFy1neE',
#  'Wr35FD-Qgj0',
#  'kvBZjKXVyP8',
#  'jbNi7aXEcJk',
#  '5jX7Fvwhm3c',
#  'u2y4QhvLWbQ',
#  'q4tO3T5krrM',
#  'Jo8aE5HUeIM',
#  'tLNEIjPfR1U',
#  'HsXy7QSqVLU',
#  '7eKnAd7FYy8',
#  'Xt-jFF6dlgk',
#  '6EhwY1xf6fw',
#  'g5pV1X0Ej08',
#  'eV_N9cuW-j4',
#  'SaNCeXsOGEg',
#  'i-zP6Pz81x8',
#  'RMMSiS_ltZc',
#  '4Dg9h7_yjww',
#  'VX4FC7w6S1g',
#  'S-ftZp4xTnk',
#  '8aUE171gzIA',
#  'O5v-4Lj43mg',
#  'Z-sjq162MOM',
#  'Q1dj-3-Yz-w',
#  '-NUx6FkXu8Q',
#  'ds4Pc3ihwGk',
#  'R4IFInWQGtk',
#  '8RN8RqkXcwA',
#  'IfbIcwG7ZAU',
#  'EMIZL5VeQIY',
#  'qahRmJspLoc',
#  'sgrc-tGRqIs',
#  'nEkYmlun9I0',
#  'Zp1iwzapuPs',
#  'L7Uxw1pAbWY',
#  'szltUYbWmIU',
#  'V9LS48jDkmI',
#  'g7lTq60pFIA',
#  'UCmo5VFAe8c',
#  'OKH5sjU-fVo',
#  'dfA54CsPNb0',
#  'TwXCZ7b1VyY',
#  'sOpw8jXvDIA',
#  'oZ12CvQh7tM',
#  'mQ6_HtCEd3A',
#  'k6ByGE3aySA',
#  '5l11R3WRDGg',
#  'IPHpqN6oR6Y',
#  'Apn4nppOflk',
#  '9DhfS8VT-u4',
#  'GBocVTSMUlk',
#  '_6FpyGvioL0',
#  'a2MbfPImgKw',
#  'g4nsC02lEsM',
#  '5vHtQMXPivE',
#  'TaKuifcP4AA',
#  'mv0lvUFN1MI',
#  'qqQB1AO0_vE',
#  'mGrlHTAxCoE',
#  'vZyqMrL0oLE',
#  'vFoqpXJhUTk',
#  'Ty1gt7EPUZs',
#  'VpCynB3LH3E',
#  'REPP3l5YjsU',
#  'Zo_K-7hhMgE',
#  '2XuXJ8LyiDc',
#  'akVjC0ZWyqw',
#  'vUJ67eMBEKU',
#  'bAJBNNQwlDE',
#  '-220Im-cYgw',
#  '7fPyJJih6bs',
#  'WWr_K0kfrz0',
#  'KehT8FXR9fU',
#  'tOLd88GWxoI',
#  'n7r7GGLLtl8',
#  'GO9jAGrcoiw',
#  'TEkwXM99kIQ',
#  'JJs9jEKWlr0',
#  'c0f0LQ05YtU',
#  'Y8i03XjQ5Xk',
#  'rjqjSC8DBV8',
#  '2v5PvTx86n0',
#  'n3eX79RDa_E',
#  '4CMnfEdnLj4',
#  'QSRaMfmwAv8',
#  'dZ06UKEkXp8',
#  'LLljt2SUqtQ',
#  '1oskzm8oyCM',
#  'YhIU8_Dz4aU',
#  'kmOvvOfYGN4',
#  'hzTN-DE8sRQ',
#  'J2g9nPY7NjY',
#  'hIR-5gWDVnU',
#  'PvNjl0oxMl0',
#  'zpHi6v3HcgE',
#  'OFjnh4cXHzQ',
#  'c_q3tyrQ6MA',
#  'g80TU1_IiDA',
#  'HIBSBkemVHE',
#  '0TnKBvWNCqo',
#  'Cd4-d6S-ldM',
#  'kKXF2VP9Qio',
#  '_eH5abTH9H8',
#  'j_wB3olOukU']

# %%
def videodetails(videoinfo):
    videodetails = []
    for i in range(0,len(videoinfo),50):
        request = youtube.videos().list(
        part="snippet,statistics",
        id=','.join(videoinfo[i:i+50])
    )
        response = request.execute()
        
        for i in range (len(response['items'])):
            videodata = dict(title_name = response['items'][i]['snippet']['title'],
                            publishing_date = response['items'][i]['snippet']['publishedAt'],
                            views = response['items'][i]['statistics']['viewCount'],
                            comments = response['items'][i]['statistics']['commentCount'],
                            likes = response['items'][i]['statistics']['likeCount'])
           
            videodetails.append(videodata)       

        return videodetails

# %%
finaldata = (videodetails(videoinfo))

# %%
finalinfo = pd.DataFrame(finaldata)

# %%
finalinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title_name       49 non-null     object
#  1   publishing_date  49 non-null     datetime64[ns, UTC]
#  2   views            49 non-null     int64
#  3   comments         49 non-null     int64
#  4   likes            49 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(3), object(1)
# memory usage: 2.0+ KB

# %%
finalinfo['views'] = pd.to_numeric(finalinfo['views'])
finalinfo['comments'] = pd.to_numeric(finalinfo['comments'])
finalinfo['likes'] = pd.to_numeric(finalinfo['likes'])

# %%
finalinfo['publishing_date'] = pd.to_datetime(finalinfo['publishing_date'])

# %%
finalinfo['month'] = finalinfo['publishing_date'].dt.month

# %%
finalinfo['year'] = finalinfo['publishing_date'].dt.year

# %%
finalinfo['yearmonth'] = finalinfo['month'].astype(str)+"-"+finalinfo['year'].astype(str)

# %%
finalinfo.sort_values(by='views',ascending=False).head(10)
# Out:
#                                            title_name  \
# 18  Fundamental Analysis of 3 Small Cap and Penny ...
# 3   Become a MILLIONAIRE by 30! - Investment Strat...
# 4   INR 1 Cr. in Stock Market | Learn Fundamental ...
# 9   How to invest your first INR 1 lakh? | Stock M...
# 29           5 GREAT stocks for long term! #Smallcase
# 39  Where to invest? | Best Mutual Funds (2021 & 2...
# 33                    How many stocks should you buy?
# 42                          A PENNY Stock worth GOLD!
# 2   Buy Low, Sell High and make money in STOCK MAR...
# 36      Start buying this FUNDAMENTALLY STRONG stock!
#
#              publishing_date    views  comments  likes  month  year yearmonth
# 18 2021-08-05 15:38:40+00:00  1910133      2710  47478      8  2021    8-2021
# 3  2021-06-19 14:50:51+00:00   695452      2352  44703      6  2021    6-2021
# 4  2021-06-12 14:37:55+00:00   599588      1955  32461      6  2021    6-2021
# 9  2021-07-03 15:08:28+00:00   584551      1977  23743      7  2021    7-2021
# 29 2021-08-31 15:00:32+00:00   576154      1197  18365      8  2021    8-2021
# 39 2021-09-30 15:00:17+00:00   571751      1553  21043      9  2021    9-2021
# 33 2021-09-13 15:14:12+00:00   527992      1924  28416      9  2021    9-2021
# 42 2021-10-10 15:00:20+00:00   505571      1083  21141     10  2021   10-2021
# 2  2021-06-18 15:50:39+00:00   499957      1940  27347      6  2021    6-2021
# 36 2021-09-25 15:05:38+00:00   489618      1333  18565      9  2021    9-2021

# %%
finalinfo.sort_values(by='comments',ascending=False).head(10)
# Out:
#                                            title_name  \
# 18  Fundamental Analysis of 3 Small Cap and Penny ...
# 3   Become a MILLIONAIRE by 30! - Investment Strat...
# 9   How to invest your first INR 1 lakh? | Stock M...
# 4   INR 1 Cr. in Stock Market | Learn Fundamental ...
# 2   Buy Low, Sell High and make money in STOCK MAR...
# 31  Should you invest in the market NOW? |#fundame...
# 33                    How many stocks should you buy?
# 11  Smallcase investing explained! (How NOT to los...
# 39  Where to invest? | Best Mutual Funds (2021 & 2...
# 13    ITC - Should you Invest? | Fundamental Analysis
#
#              publishing_date    views  comments  likes  month  year yearmonth
# 18 2021-08-05 15:38:40+00:00  1910133      2710  47478      8  2021    8-2021
# 3  2021-06-19 14:50:51+00:00   695452      2352  44703      6  2021    6-2021
# 9  2021-07-03 15:08:28+00:00   584551      1977  23743      7  2021    7-2021
# 4  2021-06-12 14:37:55+00:00   599588      1955  32461      6  2021    6-2021
# 2  2021-06-18 15:50:39+00:00   499957      1940  27347      6  2021    6-2021
# 31 2021-09-08 15:00:22+00:00   151232      1932   9248      9  2021    9-2021
# 33 2021-09-13 15:14:12+00:00   527992      1924  28416      9  2021    9-2021
# 11 2021-07-10 15:01:27+00:00   451700      1555  20242      7  2021    7-2021
# 39 2021-09-30 15:00:17+00:00   571751      1553  21043      9  2021    9-2021
# 13 2021-07-23 15:00:33+00:00   462973      1455  21580      7  2021    7-2021
